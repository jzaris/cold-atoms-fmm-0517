# %%
import math
import numpy as np
import matplotlib.pyplot as plt

N = np.array([4,64,256,512,1024])
N2 = np.array([4,64,256,512,1024, 2048])
t_orig = np.array([0.08,3,34,129,495])
t_fmm = np.array([47,50,89,149,185, 708])

fig, ax = plt.subplots()
plt.plot(N, t_orig, marker = "o")
plt.plot(N2, t_fmm, marker = "o")
ax.set_xlabel("Number of particles")
ax.set_ylabel("Time (sec)")
# Out:
# Text(0, 0.5, 'Time (sec)')
